# %% [markdown]
# # Assignment 04
#
# # LeetCode 225.
#
# class MyStack:
#
#     def __init__(self):
#         self.q = deque()
#
#     def push(self, x: int) -> None:
#         self.q.append(x)
#
#     def pop(self) -> int:
#         for i in range(len(self.q) - 1):
#             self.push(self.q.popleft())
#         return self.q.popleft()
#
#     def top(self) -> int:
#         return self.q[-1]
#
#     def empty(self) -> bool:
#         return len(self.q) == 0
#
# # LeetCode 232.
#
# class MyQueue:
#
#     def __init__(self):
#         self.input = []
#         self.output = []
#
#     def push(self, x: int) -> None:
#         self.input.append(x)
#
#     def pop(self) -> int:
#         self.peek()
#         return self.output.pop()
#
#     def peek(self) -> int:
#         if not self.output:
#             while self.input:
#                 self.output.append(self.input.pop())
#         return self.output[-1]
#
#     def empty(self) -> bool:
#         return not self.input and not self.output
#
# # 큐 연습문제.
#
# ##1.
#
# class listQueue:
#
#     def __init__(self):
#         self.__queue = []
#
#     def enqueue(self, x):
#         self.__queue.append(x) #리스트 맨끝에 요소 추가
#
#     def dequeue(self):
#         return self.__queue.pop(0) #리스트 맨 요소 제거 및 반환
#
#     def front(self):
#         return self.__queue[-1] #리스트 맨끝 요소 반환
#
#     def isEmpty(self) -> bool:
#         return len(self.__queue) == 0
#
#     def dequeueAll(self):
#         self.__queue.clear()
#
# ##2.
#
# class ListQueue:
#
#     def __init__(self):
#         self.__queue = []
#
#     def enqueue(self, x):
#         self.__queue.append(x)
#
#     def dequeue(self):
#         return self.__queue.pop(0)
#
#     def isEmpty(self) -> bool:
#         return len(self.__queue) == 0
#
#     def is_member_of_set(input):
#         queue = ListQueue()
#         queue.enqueue(input)
#
#         while nor queue.isEmpty():
#             current = queue.dequeue()
#
#             if '$' in current:
#                 parts = current.split('$')
#                 if len(parts) == 2 and parts[0] == parts[1]:
#                     return True
#         return False
#
# input = "문자열$문자열"
#
# ##3.
#
# class Node:
#     def __init__(self, data):
#         self.data = data
#         self.next = None
#
# class LinkedQueue:
#     def __init__(self):
#         self.front = None
#         self.rear = None
#
#     def enqueue(self, item):
#         new_node = Node(item)
#         if self.rear is None:
#             self.front = self.rear = new_node
#         else:
#             self.rear.next = new_node
#             self.rear = new_node
#
#     def dequeue(self):
#         if self.front is None:
#             return None
#         temp = self.front
#         self.front = self.front.next
#         if self.front is None:
#             self.rear = None
#         return temp.data
#
#     def is_empty(self):
#         return self.front is None
#
#     def copy_to(self, other_queue):
#         current = self.front
#         while current is not None:
#             other_queue.enqueue(current.data)  #데이터 복사
#             current = current.next
#
# ##4.
#
# class enefficient_push_pop:
#     def __init__(self):
#         self.queue1 = []
#         self.queue2 = []
#
#     def push(self, item): #item을 queue2에 추가
#         self.queue2.append(item)
#
#         #queue1의 모든 요소를 queue2로 이동
#         while self.queue1:
#             self.queue2.append(self.queue1.pop(0))
#
#         #queue1을 queue2로 교체
#         self.queue1, self.queue2 = self.queue2, self.queue1
#
#     def pop(self):
#         if not self.queue1:
#             return None  #스택이 비어있을 때
#         return self.queue1.pop(0)  #스택의 최상단 요소 제거 및 반환
#
# ##5.
#
# class enefficient_en_deQ:
#     def __init__(self):
#         self.stack1 = []
#         self.stack2 = []
#
#     def enqueue(self, item):
#         self.stack1.append(item)  #stack1에 요소 추가
#
#     def dequeue(self):
#         if not self.stack2:  #stack2가 비어있으면
#             while self.stack1:
#                 self.stack2.append(self.stack1.pop())  #stack1의 요소를 stack2로 이동
#         if not self.stack2:  #두 스택 모두 비어있으면
#             return None
#         return self.stack2.pop()  #큐의 앞쪽 요소 제거 및 반환
#
# ##6.
#
#  ###시간복잡도 분석
#  ###1. enqueue() : 내부적으로 CircularLinkedList의 append() 호출. 일반적인 원형 연결 리스트에서 요소 추가 연산은 맨 뒤에 추가되므로 평균적으로 O(1)의 시간복잡도
#  ###2. dequeue() : CircularLinkedList의 pop(0) 호출하여 첫 원소 삭제, 연결 리스트에서 첫 원소 삭제하는 것은 연결 재조정 필요 따라서 O(1) 복잡도 가짐. 배열 기반 리스트라면 첫 원소 삭제시 모든 요소 이동해야 하므로 O(n)의 시간 복잡도를 가지지만 이 코드에서는 연결 리스트 사용해서 O(1).
#
# ##7.
#
#  ###시간복잡도 분석
#  ###1. enqueue() : 일반적으로 연결 리스트의 맨 뒤에 요소를 추가하는 방식이지만 리스트 끝에 접근하기 위해 순회가 필요할 수 있으니 O(n)
#  ###2. dequeue() : 첫 노드 제거하는 것은 간단히 첫번째 노드를 참조하는 포인터 업데이트 작업이므로 O(1).
#
# ##8.
#
# class Deque:
#     def __init__(self):
#         self.__deque = []
#
#     def add_front(self, x):
#         self.__deque.insert(0, x)  #맨 앞에 요소 추가
#
#     def add_rear(self, x):
#         self.__deque.append(x)  #맨 뒤에 요소 추가
#
#     def remove_front(self):
#         if self.isEmpty():
#             return None  #Deque가 비어있을 때
#         return self.__deque.pop(0)  #맨 앞 요소 제거 및 반환
#
#     def remove_rear(self):
#         if self.isEmpty():
#             return None  # Deque가 비어있을 때
#         return self.__deque.pop()  #맨 뒤 요소 제거 및 반환
#
#     def front(self):
#         if self.isEmpty():
#             return None  #Deque가 비어있을 때
#         return self.__deque[0]  #맨 앞 요소 반환
#
#     def rear(self):
#         if self.isEmpty():
#             return None  #Deque가 비어있을 때
#         return self.__deque[-1]  #맨 뒤 요소 반환
#
#     def isEmpty(self) -> bool:
#         return len(self.__deque) == 0  #Deque가 비어있는지 확인
#
#     def clear(self):
#         self.__deque.clear()  #Deque의 모든 요소 제거
#
#     def printDeque(self):
#         print("Deque from front:", end=' ')
#         for item in self.__deque:
#             print(item, end=' ')
#         print()
